# %% [markdown]
# <a href="https://colab.research.google.com/github/marcushgrigsby39-web/Machine-Learning-with-python-Bootcamp./blob/main/Python___refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
tomato_price = 150
pepper_price = 80


print (tomato_price)
print (pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
# --- THE CLUES (features grouped as x) ---
rainfall_mm = 45.2     # Clue  1
bags_available = 100    # Clue  2

# --- THE GAOL (Tartget labeled as y) ---
predicted_price = 3200  # What our AI calculates

print("Inputs (X)l", rainfall_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (X)l 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding print statements

# %%
Liberia= 1847
print(Liberia)
print("Liberia")
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables

# %%
plum = 50
print("plum  previous price was:",plum)
plum = 80
print("plum newprice is:",plum)
# Out:
# plum  previous price was: 50
# plum newprice is: 80

# %% [markdown]
# Data Types

# %%
 quantity = 50
 price = 150.50
 item_name = "tomatoes"
 stall_is_open = True

 print(type(quantity))  #
 print(type(price))     #
 print(type(item_name)) #
 print(type(stall_is_open))#
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
