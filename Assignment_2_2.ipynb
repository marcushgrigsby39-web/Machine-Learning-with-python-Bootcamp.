# %% [markdown]
# <a href="https://colab.research.google.com/github/marcushgrigsby39-web/Machine-Learning-with-python-Bootcamp./blob/main/Assignment_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
transport_cost = "750"
total_delivery_cost = int(transport_cost) + 250
print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD.")
transport_cost = "750"
total_delivery_cost = int(transport_cost) + 250
print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD.")
# Out:
# Ma Christiana, your final shipping cost is: 1000 LRD.
# Ma Christiana, your final shipping cost is: 1000 LRD.

# %%
oose_stock = [45, 12, 88]
shipping_crate = [[45, 12, 88]]
oose_stock = [45, 12, 88]
shipping_crate = [[45, 12, 88]]

# %%
yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}
print(f"System Check: Tuning engine depth to {yield_model_configs['max_depth_layers']} branches.")
# Out:
# System Check: Tuning engine depth to 15 branches.

# %%
import pandas as pd

# Creating a sample DataFrame for demonstration
gobachop_data = pd.DataFrame({
    'col1': [1, 2, 3, 4, 5],
    'col2': ['A', 'B', 'C', 'D', 'E'],
    'col3': [10.1, 11.2, 12.3, 13.4, 14.5]
})

print(gobachop_data.head(1))
# Out:
#    col1 col2  col3
# 0     1    A  10.1
