# %% [markdown]
# <a href="https://colab.research.google.com/github/marcushgrigsby39-web/Machine-Learning-with-python-Bootcamp./blob/main/lib_intro2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.DataFrame({
"Owner" : ["Ma Musu", "Sia"],
"Revenue": [5000,7000]

})

# ATTRIBUTE (no parentheses)
print(f"Data Grid Shape:) {data. shape}")  # (2,2)

# METHOD (parentheses)
print("frist row")
print(data.head)
# Out:
# Data Grid Shape:) (2, 2)
# frist row
# <bound method NDFrame.head of      Owner  Revenue
# 0  Ma Musu     5000
# 1      Sia     7000>

# %%
data = [1,2,3,4,5,6,7]
print(data[1:6])
print(data[6])
print(data[-1])
# Out:
# [2, 3, 4, 5, 6]
# 7
# 7

# %%
print("Mageret"+"Thanter")
print("Mageret" + "   Thanter")
# Out:
# MageretThanter
# Mageret   Thanter

# %%
import pandas as pd
gobachop_data = pd.DataFrame({
    "vendor": ["Ma Musu", "Sia", "Flomo"],
    "Sale":[4000, 9500, 1500]
})
print(gobachop_data.head())
# Out:
#     vendor  Sale
# 0  Ma Musu  4000
# 1      Sia  9500
# 2    Flomo  1500

# %%
import numpy as np
# Daily gari price at Gobachop Market (LRD per bag)
prices = np.array([850, 900, 875, 920, 860, 910, 895])
print('prices:',             prices )
print('Mean price:',        np.mean(prices))
print('Median price:',      np.median(prices))
print('Highest:',           np.max(prices))
print('Lowest:',             np.min(prices))
print('Sts Dev:',           np.std(prices).round(2))
# Out:
# prices: [850 900 875 920 860 910 895]
# Mean price: 887.1428571428571
# Median price: 895.0
# Highest: 920
# Lowest: 850
# Sts Dev: 24.18
